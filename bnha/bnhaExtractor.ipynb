# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
response = requests.get(
	url="https://myheroacademia.fandom.com/wiki/List_of_Characters",
)
print(response.status_code) 

soup = BeautifulSoup(response.content, 'html.parser')
print(soup)
# Out:
# 200
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Characters | My Hero Academia Wiki | Fandom</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
title = soup.find(div="firstHeading")
print(title.string)
# Out:
# 					List of Characters

# %%
# Get all the links
allLinks = soup.find(id="mw-content-text").find_all("a")
linkToScrape = 0

for link in allLinks:
	# We are only interested in other wiki articles
	if link['href'].find("/wiki/") == -1: 
		continue

	# Use this link to scrape
	linkToScrape = link
	break

print(linkToScrape)
# Out:
# <a href="/wiki/My_Hero_Academia_(Manga)" title="My Hero Academia (Manga)"><i>My Hero Academia</i> manga</a>

# %%
response = requests.get(
	url="https://myheroacademia.fandom.com/wiki/Nezu",
)
soup = BeautifulSoup(response.content, 'html.parser')
print(response.status_code) 


# title = soup.find_all(True, {"class": ["pi-data-label pi-secondary-font","pi-data-value pi-font"]})
title = []
for i in soup.find_all("section", "pi-item pi-group pi-border-color"):
	temp = i.find(True, {"class": ["pi-data-label pi-secondary-font","pi-data-value pi-font"]})
	title = title + temp.get_text(strip=True)
	
title = [elem.get_text() for elem in title]

# # Get all the links
# allLinks = soup.find(id="mw-content-text").find_all("a")
# linkToScrape = 0
# print(allLinks)
# Out:
# 200
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Idiot 2\Documents\blogDump\bnha\bnhaExtractor.ipynb Cell 5' in <cell line: 10>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Idiot%202/Documents/blogDump/bnha/bnhaExtractor.ipynb#ch0000005?line=9'>10</a> for i in soup.find_all("section", "pi-item pi-group pi-border-color"):
#      <a href='vscode-notebook-cell:/c%3A/Users/Idiot%202/Documents/blogDump/bnha/bnhaExtractor.ipynb#ch0000005?line=10'>11</a> 	temp = i.find(True, {"class": ["pi-data-label pi-secondary-font","pi-data-value pi-font"]})
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Idiot%202/Documents/blogDump/bnha/bnhaExtractor.ipynb#ch0000005?line=11'>12</a> 	title = title + temp.get_text(strip=True)
# ...

# %%
#cleaning:

toClean = str(title)
toClean = toClean.strip('\n')
toClean= toClean.strip('\t')
toClean
# Out:
# '[<h3 class="pi-data-label pi-secondary-font">Kanji Name</h3>, <div class="pi-data-value pi-font"><span lang="ja"><ruby lang="ja"><rb style="text-justify:inter-word">根</rb><rp> (</rp><rt>ね</rt><rp>) </rp></ruby><ruby lang="ja"><rb style="text-justify:inter-word">津</rb><rp> (</rp><rt>づ</rt><rp>) </rp></ruby></span></div>, <h3 class="pi-data-label pi-secondary-font">Rōmaji Name</h3>, <div class="pi-data-value pi-font"><i>Nedzu</i></div>, <h3 class="pi-data-label pi-secondary-font">Birthday</h3>, <div class="pi-data-value pi-font">January 1<sup class="reference" id="cite_ref-auto-79d8f7c8e2566e9adf0a76dd550c5931_1-0"><a href="#cite_note-auto-79d8f7c8e2566e9adf0a76dd550c5931-1">[1]</a></sup></div>, <h3 class="pi-data-label pi-secondary-font">Gender</h3>, <div class="pi-data-value pi-font"><a href="/wiki/Category:Males" title="Category:Males"><img alt="Male.png" data-image-key="Male.png" data-image-name="Male.png" decoding="async" height="15" src="https://static.wikia.nocookie.net/bokunoh
# ...
